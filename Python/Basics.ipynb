# %% [markdown]
# # This is line1

# %% [markdown]
# ## This is line1

# %% [markdown]
# ### This is line1
#
# #### This is line1
#
# ##### This is line1
#
# ###### This is line1

# %%
a = 2
b = 3

print(a+b)
a = 2
b = 3

# print(a+b)a = 2
# b = 3
# print(a+b)a = 2
# b = 3

# %%
# print(a+b)a = 2
# b = 3

# %%
# print(a+b)a = 2
b = 3
print(a+b)
# Out:
# 5

# %%
a = 3
print(a)

# %% [markdown]
# # This is line1

# %% [markdown]
# ## This is line1

# %% [markdown]
# ### This is line1

# %% [markdown]
# #### This is line1

# %% [markdown]
# ##### This is line1

# %% [markdown]
# ###### This is line1
